# %%
# configuration
import matplotlib.pyplot as plt

free = ["ended_results_", "ended_results_goSide_", "ended_results_goback_"]
grid = ["ended_results_grid_", "ended_results_grid_goSide_", "ended_results_grid_goback_"]
size = ["10", "20", "30", "40", "50", "60", "70"]
size_int = range(10, 80, 10)
robots = ["2", "5", "7", "10"]
points = ["3", "8"]
options_free = ["100", "101", "201", "110", "111", "211"]
options_grid = ["110", "111", "211"]

# %%
# time split

for name in free:
    file_name = "ended_results/" + str(name) + ".txt"
    with open(file_name, 'r') as f:
        for line in f:
            data = line.split(" ")
            with open("finish_time/" + str(name) + data[2] + "_" + data[3] + "_" + data[4] + ".txt", 'w') as f:
                f.write("")

for name in grid:
    file_name = "ended_results/" + str(name) + ".txt"
    with open(file_name, 'r') as f:
        for line in f:
            data = line.split(" ")
            with open("finish_time/" + str(name) + data[2] + "_" + data[3] + "_" + data[4] + ".txt", 'w') as f:
                f.write("")

for name in free:
    file_name = "ended_results/" + str(name) + ".txt"
    with open(file_name, 'r') as f:
        for line in f:
            data = line.split(" ")
            with open("finish_time/" + str(name) + data[2] + "_" + data[3] + "_" + data[4] + ".txt", 'a') as f:
                f.write(data[0] + " " + data[8] + "\n")

for name in grid:
    file_name = "ended_results/" + str(name) + ".txt"
    with open(file_name, 'r') as f:
        for line in f:
            data = line.split(" ")
            with open("finish_time/" + str(name) + data[2] + "_" + data[3] + "_" + data[4] + ".txt", 'a') as f:
                f.write(data[0] + " " + data[8] + "\n")

# %%
# percent split

for name in free:
    file_name = "ended_results/" + str(name) + ".txt"
    with open(file_name, 'r') as f:
        for line in f:
            data = line.split(" ")
            with open("finish_percent/" + str(name) + data[2] + "_" + data[3] + "_" + data[4] + ".txt", 'w') as f:
                f.write("")

for name in grid:
    file_name = "ended_results/" + str(name) + ".txt"
    with open(file_name, 'r') as f:
        for line in f:
            data = line.split(" ")
            with open("finish_percent/" + str(name) + data[2] + "_" + data[3] + "_" + data[4] + ".txt", 'w') as f:
                f.write("")

for name in free:
    file_name = "ended_results/" + str(name) + ".txt"
    with open(file_name, 'r') as f:
        for line in f:
            data = line.split(" ")
            with open("finish_percent/" + str(name) + data[2] + "_" + data[3] + "_" + data[4] + ".txt", 'a') as f:
                f.write(data[0] + " " + str(int(data[9])/int(data[7])*100) + " " + str(int(data[5])/(int(data[0])*int(data[0])*int(data[2])/100)*int(data[7])) + "\n")

for name in grid:
    file_name = "ended_results/" + str(name) + ".txt"
    with open(file_name, 'r') as f:
        for line in f:
            data = line.split(" ")
            with open("finish_percent/" + str(name) + data[2] + "_" + data[3] + "_" + data[4] + ".txt", 'a') as f:
                f.write(data[0] + " " + str(int(data[9])/int(data[7])*100) + " " + str(int(data[5])/(int(data[0])*int(data[0])*int(data[2])/100)*int(data[7])) + "\n")

# %%
time_results = {}

for name in free:
    time_results[name] = {}
    for robot in robots:
        time_results[name][robot] = {}
        for point in points:
            time_results[name][robot][point] = {}
            for option in options_free:
                time_results[name][robot][point][option] = []
                file_name = "finish_time/" + str(name) + str(robot) + "_" + str(point) + "_" + str(option) + ".txt"
                with open(file_name) as f:
                    for line in f:
                        data = line.split(" ")
                        time = data[0]
                        time_results[name][robot][point][option].append(time)


for name in grid:
    time_results[name] = {}
    for robot in robots:
        time_results[name][robot] = {}
        for point in points:
            time_results[name][robot][point] = {}
            for option in options_grid:
                time_results[name][robot][point][option] = []
                file_name = "finish_time/" + str(name) + str(robot) + "_" + str(point) + "_" + str(option) + ".txt"
                with open(file_name) as f:
                    for line in f:
                        data = line.split(" ")
                        time = data[0]
                        time_results[name][robot][point][option].append(time)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Maialen\Desktop\Deadlock-handling-in-multi-mobile-robot-systems\graphs.ipynb Cell 4' in <module>
#      <a href='vscode-notebook-cell:/c%3A/Users/Maialen/Desktop/Deadlock-handling-in-multi-mobile-robot-systems/graphs.ipynb#ch0000003?line=9'>10</a> time_results[name][robot][point][option] = []
#      <a href='vscode-notebook-cell:/c%3A/Users/Maialen/Desktop/Deadlock-handling-in-multi-mobile-robot-systems/graphs.ipynb#ch0000003?line=10'>11</a> file_name = "finish_time/" + str(name) + str(robot) + "_" + str(point) + "_" + str(option) + ".txt"
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Maialen/Desktop/Deadlock-handling-in-multi-mobile-robot-systems/graphs.ipynb#ch0000003?line=11'>12</a> with open(file_name) as f:
# ...

# %%
percent_results = {}

for name in free:
    percent_results[name] = {}
    for robot in robots:
        percent_results[name][robot] = {}
        for point in points:
            percent_results[name][robot][point] = {}
            for option in options_free:
                percent_results[name][robot][point][option] = []
                file_name = "finish_percent/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt"
                with open(file_name) as f:
                    for line in f:
                        data = line.split(" ")
                        time = data[0]
                        percent_results[name][robot][point][option].append(time)

for name in grid:
    percent_results[name] = {}
    for robot in robots:
        percent_results[name][robot] = {}
        for point in points:
            percent_results[name][robot][point] = {}
            for option in options_grid:
                percent_results[name][robot][point][option] = []
                file_name = "finish_percent/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt"
                with open(file_name) as f:
                    for line in f:
                        data = line.split(" ")
                        time = data[0]
                        percent_results[name][robot][point][option].append(time)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Maialen\Desktop\Deadlock-handling-in-multi-mobile-robot-systems\graphs.ipynb Cell 5' in <module>
#      <a href='vscode-notebook-cell:/c%3A/Users/Maialen/Desktop/Deadlock-handling-in-multi-mobile-robot-systems/graphs.ipynb#ch0000004?line=9'>10</a> percent_results[name][robot][point][option] = []
#      <a href='vscode-notebook-cell:/c%3A/Users/Maialen/Desktop/Deadlock-handling-in-multi-mobile-robot-systems/graphs.ipynb#ch0000004?line=10'>11</a> file_name = "finish_percent/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt"
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Maialen/Desktop/Deadlock-handling-in-multi-mobile-robot-systems/graphs.ipynb#ch0000004?line=11'>12</a> with open(file_name) as f:
# ...

# %%
# graph time free
x = []
y = []

for name in free:
    for robot in robots:
        for point in points:
            for option in options_free:
                with open("finish_time/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt") as f:
                    x = []
                    y = []
                    for line in f:
                        data = line.split(" ")
                        x.append(int(data[0]))
                        y.append(float(data[1]))
                    if int(point) == 3:
                        plt.plot(x, y, label=str(robot) + "% " + str(point) + " " + str(option))
                    else:
                        plt.plot(x, y, linestyle='--', label=str(robot) + "% " + str(point) + " " + str(option))
        plt.grid(linestyle='--')
        plt.title("Time of performing simulation - " + name)
        plt.xlabel("size [NxN]")
        plt.ylabel("time [ms]")
        plt.legend()
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Maialen\Desktop\Deadlock-handling-in-multi-mobile-robot-systems\graphs.ipynb Cell 6' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Maialen/Desktop/Deadlock-handling-in-multi-mobile-robot-systems/graphs.ipynb#ch0000005?line=6'>7</a> for point in points:
#       <a href='vscode-notebook-cell:/c%3A/Users/Maialen/Desktop/Deadlock-handling-in-multi-mobile-robot-systems/graphs.ipynb#ch0000005?line=7'>8</a>     for option in options_free:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Maialen/Desktop/Deadlock-handling-in-multi-mobile-robot-systems/graphs.ipynb#ch0000005?line=8'>9</a>         with open("finish_time/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt") as f:
# ...

# %%
# graph time grid
x = []
y = []

for name in grid:
    for robot in robots:
        for point in points:
            for option in options_grid:
                with open("finish_time/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt") as f:
                    x = []
                    y = []
                    for line in f:
                        data = line.split(" ")
                        x.append(int(data[0]))
                        y.append(float(data[1]))
                    if int(point) == 3:
                        plt.plot(x, y, label=str(robot) + "% " + str(point) + " " + str(option))
                    else:
                        plt.plot(x, y, linestyle='--', label=str(robot) + "% " + str(point) + " " + str(option))
        plt.grid(linestyle='--')
        plt.title("Time of performing simulation - " + name)
        plt.xlabel("size [NxN]")
        plt.ylabel("time [ms]")
        plt.legend()
        plt.show()

# %%
# graph percent free
x = []
y = []

for name in free:
    for robot in robots:
        for point in points:
            for option in options_free:
                with open("finish_percent/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt") as f:
                    x = []
                    y = []
                    for line in f:
                        data = line.split(" ")
                        x.append(int(data[0]))
                        y.append(float(data[1]))
                    if int(point) == 3:
                        plt.plot(x, y, label=str(robot) + "% " + str(point) + " " + str(option))
                    else:
                        plt.plot(x, y, linestyle='--', label=str(robot) + "% " + str(point) + " " + str(option))
        plt.grid(linestyle='--')
        plt.title("percent of performing simulation - " + name)
        plt.xlabel("size [NxN]")
        plt.ylabel("percent [%]")
        plt.legend()
        plt.show()

# %%
# graph percent grid
x = []
y = []

for name in grid:
    for robot in robots:
        for point in points:
            for option in options_grid:
                with open("finish_percent/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt") as f:
                    x = []
                    y = []
                    for line in f:
                        data = line.split(" ")
                        x.append(int(data[0]))
                        y.append(float(data[1]))
                    if int(point) == 3:
                        plt.plot(x, y, label=str(robot) + "% " + str(point) + " " + str(option))
                    else:
                        plt.plot(x, y, linestyle='--', label=str(robot) + "% " + str(point) + " " + str(option))
        plt.grid(linestyle='--')
        plt.title("percent of performing simulation - " + name)
        plt.xlabel("size [NxN]")
        plt.ylabel("percent [%]")
        plt.legend()
        plt.show()

# %%
# graph time for robot = "7", point = "8", option = "111"
x = []
y = []

robot = "7"
point = "8"
option = "111"

side = free + grid

plt.figure(dpi=100, figsize=[8, 6])

for name in side:
    with open("finish_time/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt") as f:
        x = []
        y = []
        for line in f:
            data = line.split(" ")
            x.append(int(data[0]))
            y.append(float(data[1]))
        plt.plot(x, y, label=str(name))
plt.grid(linestyle='--')
plt.title("Time of performing simulation - ")
plt.xlabel("size [NxN]")
plt.ylabel("time [ms]")
plt.legend(loc='upper left')
plt.show()

for name in side:
    with open("finish_time/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt") as f:
        x = []
        y = []
        for line in f:
            data = line.split(" ")
            x.append(int(data[0]))
            y.append(float(data[1]))
        plt.plot(x, y, label=str(name))
plt.grid(linestyle='--')
plt.title("Time of performing simulation - ")
plt.xlabel("size [NxN]")
plt.ylabel("time [ms]")
plt.legend(loc='upper left')
plt.xlim([40, 60])
plt.ylim([-100, 800])
plt.show()

# %%
# graph percent for robot = "5", point = "8", option = "111"
x = []
y = []

robot = "5"
point = "8"
option = "111"
i = 0
side = free + grid


plt.figure(dpi=100, figsize=[8, 6])

for name in side:
    with open("finish_percent/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt") as f:
        x = []
        y = []
        for line in f:
            data = line.split(" ")
            x.append(int(data[0]))
            y.append(float(data[1]))
        if i == 0:
            plt.plot(x, y, '-s', label=str(name))
            i += 1
        elif i == 1:
            plt.plot(x, y, '-o', label=str(name))
            i += 1
        elif i == 2:
            plt.plot(x, y, marker='D', label=str(name))
            i += 1
        else:
            plt.plot(x, y, '-*', label=str(name))
            i = 0
plt.grid(linestyle='--')
plt.title("{P}ercent of performing simulation - ")
plt.xlabel("size [NxN]")
plt.ylabel("percent [%]")
plt.legend(loc='lower right')
plt.show()

# for name in side:
#     with open("finish_percent/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt") as f:
#         x = []
#         y = []
#         for line in f:
#             data = line.split(" ")
#             x.append(int(data[0]))
#             y.append(float(data[1]))
#         plt.plot(x, y, label=str(name))
# plt.grid(linestyle='--')
# plt.title("Time of performing simulation - ")
# plt.xlabel("size [NxN]")
# plt.ylabel("time [ms]")
# plt.legend(loc='upper left')
# plt.xlim([40, 60])
# plt.ylim([-100, 800])
# plt.show()

# %%
# graph time all for robot = "7", point = "8", option = "101, 111"
x = []
y = []

robot = "7"
point = "8"

side = free + grid

plt.figure(dpi=100, figsize=[8, 6])

option = "101"
for name in free:
    with open("finish_time/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt") as f:
        x = []
        y = []
        for line in f:
            data = line.split(" ")
            x.append(int(data[0]))
            y.append(float(data[1]))
        plt.plot(x, y, label=str(name) + "_" + str(option))

option = "111"
for name in side:
    with open("finish_time/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt") as f:
        x = []
        y = []
        for line in f:
            data = line.split(" ")
            x.append(int(data[0]))
            y.append(float(data[1]))
        plt.plot(x, y, label=str(name) + "_" + str(option))

plt.grid(linestyle='--')
plt.title("Time of performing simulation - ")
plt.xlabel("size [NxN]")
plt.ylabel("time [ms]")
plt.legend(loc='upper left')
plt.show()

option = "101"
for name in free:
    with open("finish_time/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt") as f:
        x = []
        y = []
        for line in f:
            data = line.split(" ")
            x.append(int(data[0]))
            y.append(float(data[1]))
        plt.plot(x, y, label=str(name) + "_" + str(option))

option = "111"
for name in side:
    with open("finish_time/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt") as f:
        x = []
        y = []
        for line in f:
            data = line.split(" ")
            x.append(int(data[0]))
            y.append(float(data[1]))
        plt.plot(x, y, label=str(name) + "_" + str(option))
plt.grid(linestyle='--')
plt.title("Time of performing simulation - ")
plt.xlabel("size [NxN]")
plt.ylabel("time [ms]")
plt.legend(loc='upper left')
plt.xlim([40, 60])
plt.ylim([-100, 500])
plt.show()

# %%
# graph percent all for robot = "7", point = "8", option = "101, 111"
x = []
y = []

robot = "7"
point = "8"

side = free + grid

plt.figure(dpi=100, figsize=[8, 6])
i = 0
option = "101"
for name in free:
    with open("finish_percent/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt") as f:
        x = []
        y = []
        for line in f:
            data = line.split(" ")
            x.append(int(data[0]))
            y.append(float(data[1]))
        if i == 0:
            plt.plot(x, y, '-s', label=str(name) + "_" + str(option))
            i += 1
        elif i == 1:
            plt.plot(x, y, '-o', label=str(name) + "_" + str(option))
            i += 1
        elif i == 2:
            plt.plot(x, y, marker='D', label=str(name) + "_" + str(option))
            i += 1
        else:
            plt.plot(x, y, '-*', label=str(name) + "_" + str(option))
            i = 0

option = "111"
for name in side:
    with open("finish_percent/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt") as f:
        x = []
        y = []
        for line in f:
            data = line.split(" ")
            x.append(int(data[0]))
            y.append(float(data[1]))
        if i == 0:
            plt.plot(x, y, '-s', label=str(name) + "_" + str(option))
            i += 1
        elif i == 1:
            plt.plot(x, y, '-o', label=str(name) + "_" + str(option))
            i += 1
        elif i == 2:
            plt.plot(x, y, marker='D', label=str(name) + "_" + str(option))
            i += 1
        else:
            plt.plot(x, y, '-*', label=str(name) + "_" + str(option))
            i = 0

plt.grid(linestyle='--')
plt.title("percent of performing simulation - ")
plt.xlabel("size [NxN]")
plt.ylabel("percent [%]")
plt.legend(loc='center left')
plt.show()

# %%
# graph time all for robot = "2, 5, 7, 10", point = "3", option = "111"
x = []
y = []

robots = ["2", "5", "7", "10"]
point = "3"
names = ["ended_results_goSide_", "ended_results_grid_goSide_"]
i = 0
option = "111"

plt.figure(dpi=100, figsize=[8, 6])
for name in names:
    for robot in robots:
        with open("finish_time/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt") as f:
            x = []
            y = []
            for line in f:
                data = line.split(" ")
                x.append(int(data[0]))
                y.append(float(data[1]))
            if i == 0:
                plt.plot(x, y, '-s', label=str(name) + "_" + str(robot))
                i += 1
            elif i == 1:
                plt.plot(x, y, '-o', label=str(name) + "_" + str(robot))
                i += 1
            elif i == 2:
                plt.plot(x, y, marker='D', label=str(name) + "_" + str(robot))
                i += 1
            else:
                plt.plot(x, y, '-*', label=str(name) + "_" + str(robot))
                i = 0

plt.grid(linestyle='--')
plt.title("Time of performing simulation - ")
plt.xlabel("size [NxN]")
plt.ylabel("time [ms]")
plt.legend(loc='center left')
plt.show()

# %%
# graph percent all for robot = "2, 5, 7, 10", point = "8", option = "111"
x = []
y = []

robots = ["2", "5", "7", "10"]
point = "3"
names = ["ended_results_goSide_", "ended_results_grid_goSide_"]
i = 0
option = "111"

plt.figure(dpi=100, figsize=[8, 6])
for name in names:
    for robot in robots:
        with open("finish_percent/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt") as f:
            x = []
            y = []
            for line in f:
                data = line.split(" ")
                x.append(int(data[0]))
                y.append(float(data[1]))
            if i == 0:
                plt.plot(x, y, '-s', label=str(name) + "_" + str(robot))
                i += 1
            elif i == 1:
                plt.plot(x, y, '-o', label=str(name) + "_" + str(robot))
                i += 1
            elif i == 2:
                plt.plot(x, y, marker='D', label=str(name) + "_" + str(robot))
                i += 1
            else:
                plt.plot(x, y, '-*', label=str(name) + "_" + str(robot))
                i = 0

plt.grid(linestyle='--')
plt.title("percent of performing simulation - ")
plt.xlabel("size [NxN]")
plt.ylabel("percent [%]")
plt.legend(loc='center left')
plt.show()

# %%
# graph time free goSide 5%
x = []
y = []

name = "ended_results_goSide_"
robot = "5"

plt.figure(dpi=100, figsize=[8, 6])

for point in points:
    for option in options_free:
        with open("finish_time/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt") as f:
            x = []
            y = []
            for line in f:
                data = line.split(" ")
                x.append(int(data[0]))
                y.append(float(data[1]))
            method = ""
            if option[1] == "0":
                method = "Euclidean"
            else:
                method = "Manhattan"
            if option[2] == "1":
                if option[0] == "1":
                    method += ", RAS - max capacity: 1"
                else:
                    method += ", RAS - max capacity: 2"
            if int(point) == 3:
                plt.plot(x, y, label="Points: [1-4], " + method)
            else:
                plt.plot(x, y, linestyle='--', label="Points: [6-9], " + method)
plt.grid(linestyle='--')
plt.title("Time of performing simulation - Method: go to the side, Robots: 5% of cells number")
plt.xlabel("size [NxN]")
plt.ylabel("time [ms]")
plt.legend()
plt.show()

# %%
# graph percent free goSide 5%
x = []
y = []

name = "ended_results_goSide_"
robot = "2"

plt.figure(dpi=100, figsize=[8, 6])

for point in points:
    for option in options_free:
        with open("finish_percent/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt") as f:
            x = []
            y = []
            for line in f:
                data = line.split(" ")
                x.append(int(data[0]))
                y.append(float(data[1]))
            method = ""
            if option[1] == "0":
                method = "Euclidean"
            else:
                method = "Manhattan"
            if option[2] == "1":
                if option[0] == "1":
                    method += ", RAS - max capacity: 1"
                else:
                    method += ", RAS - max capacity: 2"
            if int(point) == 3:
                plt.plot(x, y, label="Points: [1-4], " + method)
            else:
                plt.plot(x, y, linestyle='--', label="Points: [6-9], " + method)
plt.grid(linestyle='--')
plt.title("Percentage of finished tasks - Method: go to the side, Robots: 5% of cells number")
plt.xlabel("size [NxN]")
plt.ylabel("time [ms]")
plt.legend()
plt.show()
