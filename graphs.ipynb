# %%
time_results = {}

free = ["ended_results", "ended_results_goSide", "ended_results_goback"]
grid = ["ended_results_grid", "ended_results_grid_goSide", "ended_results_grid_goback"]
robots = ["2", "5", "7", "10"]
points = ["3", "8"]
options_free = ["100", "101", "201", "110", "111", "211"]
options_grid = ["110", "111", "211"]

for name in free:
    time_results[free] = {}
    for robot in robots:
        time_results[name][robot] = {}
        for point in points:
            time_results[name][robot][point] = {}
            for option in options_free:
                time_results[name][robot][point][option] = []
                file_name = "ended_results/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt"
                with open(file_name) as f:
                    for line in f:
                        data = line.split(" ")
                        time = data[0]
                        time_results[name][robot][point][option].append(time)


for name in grid:
    time_results[name] = {}
    for robot in robots:
        time_results[name][robot] = {}
        for point in points:
            time_results[name][robot][point] = {}
            for option in options_grid:
                time_results[name][robot][point][option] = []
                file_name = "ended_results/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt"
                with open(file_name) as f:
                    for line in f:
                        data = line.split(" ")
                        time = data[0]
                        time_results[name][robot][point][option].append(time)

# %%
percent_results = {}

free = ["ended_results", "ended_results_goSide", "ended_results_goback"]
grid = ["ended_results_grid", "ended_results_grid_goSide", "ended_results_grid_goback"]
robots = ["2", "5", "7", "10"]
points = ["3", "8"]
options_free = ["100", "101", "201", "110", "111", "211"]
options_grid = ["110", "111", "211"]

for name in free:
    percent_results[free] = {}
    for robot in robots:
        percent_results[name][robot] = {}
        for point in points:
            percent_results[name][robot][point] = {}
            for option in options_free:
                percent_results[name][robot][point][option] = []
                file_name = "ended_results/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt"
                with open(file_name) as f:
                    for line in f:
                        data = line.split(" ")
                        time = data[0]
                        percent_results[name][robot][point][option].append(time)

for name in grid:
    percent_results[name] = {}
    for robot in robots:
        percent_results[name][robot] = {}
        for point in points:
            percent_results[name][robot][point] = {}
            for option in options_grid:
                percent_results[name][robot][point][option] = []
                file_name = "ended_results/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt"
                with open(file_name) as f:
                    for line in f:
                        data = line.split(" ")
                        time = data[0]
                        percent_results[name][robot][point][option].append(time)

# %%
import matplotlib.pyplot as plt

free = ["ended_results", "ended_results_goSide", "ended_results_goback"]
grid = ["ended_results_grid", "ended_results_grid_goSide", "ended_results_grid_goback"]
robots = ["2", "5", "7", "10"]
points = ["3", "8"]
options_free = ["100", "101", "201", "110", "111", "211"]
options_grid = ["110", "111", "211"]
size = range(10, 80, 10)

# plt.plot(size, time_results[name][robot][point][option], color='tab:red', linestyle='--', label="My (f32)")
plt.plot(size, time_results[name][robot][point][option], label="My (f32)")

plt.grid(linestyle='--')
plt.title("Scalars Squareroot - F7 board - My vs CMSIS - i16 vs i32 vs f32")
plt.xlabel("Number idx")
plt.ylabel("ms")
plt.legend()

plt.show()
