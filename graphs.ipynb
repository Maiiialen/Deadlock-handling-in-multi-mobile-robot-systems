# %%
free = ["ended_results_", "ended_results_goSide_", "ended_results_goback_"]
grid = ["ended_results_grid_", "ended_results_grid_goSide_", "ended_results_grid_goback_"]
size = ["10", "20", "30", "40", "50", "60", "70"]
robots = ["2", "5", "7", "10"]
points = ["3", "8"]
options_free = ["100", "101", "201", "110", "111", "211"]
options_grid = ["110", "111", "211"]

# %%
# time split

for name in free:
    file_name = "ended_results/" + str(name) + ".txt"
    with open(file_name, 'r') as f:
        for line in f:
            data = line.split(" ")
            with open("finish_time/" + str(name) + "_" + data[2] + "_" + data[3] + "_" + data[4] + ".txt", 'w') as f:
                f.write("")

for name in grid:
    file_name = "ended_results/" + str(name) + ".txt"
    with open(file_name, 'r') as f:
        for line in f:
            data = line.split(" ")
            with open("finish_time/" + str(name) + "_" + data[2] + "_" + data[3] + "_" + data[4] + ".txt", 'w') as f:
                f.write("")

for name in free:
    file_name = "ended_results/" + str(name) + ".txt"
    with open(file_name, 'r') as f:
        for line in f:
            data = line.split(" ")
            with open("finish_time/" + str(name) + "_" + data[2] + "_" + data[3] + "_" + data[4] + ".txt", 'a') as f:
                f.write(data[0] + " " + data[8] + "\n")

for name in grid:
    file_name = "ended_results/" + str(name) + ".txt"
    with open(file_name, 'r') as f:
        for line in f:
            data = line.split(" ")
            with open("finish_time/" + str(name) + "_" + data[2] + "_" + data[3] + "_" + data[4] + ".txt", 'a') as f:
                f.write(data[0] + " " + data[8] + "\n")

# %%
# percent split

for name in free:
    file_name = "ended_results/" + str(name) + ".txt"
    with open(file_name, 'r') as f:
        for line in f:
            data = line.split(" ")
            with open("finish_percent/" + str(name) + "_" + data[2] + "_" + data[3] + "_" + data[4] + ".txt", 'w') as f:
                f.write("")

for name in grid:
    file_name = "ended_results/" + str(name) + ".txt"
    with open(file_name, 'r') as f:
        for line in f:
            data = line.split(" ")
            with open("finish_percent/" + str(name) + "_" + data[2] + "_" + data[3] + "_" + data[4] + ".txt", 'w') as f:
                f.write("")

for name in free:
    file_name = "ended_results/" + str(name) + ".txt"
    with open(file_name, 'r') as f:
        for line in f:
            data = line.split(" ")
            with open("finish_percent/" + str(name) + "_" + data[2] + "_" + data[3] + "_" + data[4] + ".txt", 'a') as f:
                f.write(data[0] + " " + str(int(data[9])/int(data[7])*100) + " " + str(int(data[5])/(int(data[0])*int(data[0])*int(data[2])/100)*int(data[7])) + "\n")

for name in grid:
    file_name = "ended_results/" + str(name) + ".txt"
    with open(file_name, 'r') as f:
        for line in f:
            data = line.split(" ")
            with open("finish_percent/" + str(name) + "_" + data[2] + "_" + data[3] + "_" + data[4] + ".txt", 'a') as f:
                f.write(data[0] + " " + str(int(data[9])/int(data[7])*100) + " " + str(int(data[5])/(int(data[0])*int(data[0])*int(data[2])/100)*int(data[7])) + "\n")

# %%
time_results = {}

for name in free:
    time_results[name] = {}
    for robot in robots:
        time_results[name][robot] = {}
        for point in points:
            time_results[name][robot][point] = {}
            for option in options_free:
                time_results[name][robot][point][option] = []
                file_name = "finish_time/" + str(name) + str(robot) + "_" + str(point) + "_" + str(option) + ".txt"
                with open(file_name) as f:
                    for line in f:
                        data = line.split(" ")
                        time = data[0]
                        time_results[name][robot][point][option].append(time)


for name in grid:
    time_results[name] = {}
    for robot in robots:
        time_results[name][robot] = {}
        for point in points:
            time_results[name][robot][point] = {}
            for option in options_grid:
                time_results[name][robot][point][option] = []
                file_name = "finish_time/" + str(name) + str(robot) + "_" + str(point) + "_" + str(option) + ".txt"
                with open(file_name) as f:
                    for line in f:
                        data = line.split(" ")
                        time = data[0]
                        time_results[name][robot][point][option].append(time)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Maialen\Desktop\Deadlock-handling-in-multi-mobile-robot-systems\graphs.ipynb Cell 4' in <module>
#      <a href='vscode-notebook-cell:/c%3A/Users/Maialen/Desktop/Deadlock-handling-in-multi-mobile-robot-systems/graphs.ipynb#ch0000000?line=9'>10</a> time_results[name][robot][point][option] = []
#      <a href='vscode-notebook-cell:/c%3A/Users/Maialen/Desktop/Deadlock-handling-in-multi-mobile-robot-systems/graphs.ipynb#ch0000000?line=10'>11</a> file_name = "ended_results/" + str(name) + str(robot) + "_" + str(point) + "_" + str(option) + ".txt"
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Maialen/Desktop/Deadlock-handling-in-multi-mobile-robot-systems/graphs.ipynb#ch0000000?line=11'>12</a> with open(file_name) as f:
#      <a href='vscode-notebook-cell:/c%3A/Users/Maialen/Desktop/Deadlock-handling-in-multi-mobile-robot-systems/graphs.ipynb#ch0000000?line=12'>13</a>     for line in f:
#      <a href='vscode-notebook-cell:/c%3A/Users/Maialen/Desktop/Deadlock-handling-in-multi-mobile-robot-systems/graphs.ipynb#ch0000000?line=13'>14</a>         data = line.split(" ")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ended_results/ended_results_2_3_100.txt'

# %%
percent_results = {}

for name in free:
    percent_results[free] = {}
    for robot in robots:
        percent_results[name][robot] = {}
        for point in points:
            percent_results[name][robot][point] = {}
            for option in options_free:
                percent_results[name][robot][point][option] = []
                file_name = "finish_percent/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt"
                with open(file_name) as f:
                    for line in f:
                        data = line.split(" ")
                        time = data[0]
                        percent_results[name][robot][point][option].append(time)

for name in grid:
    percent_results[name] = {}
    for robot in robots:
        percent_results[name][robot] = {}
        for point in points:
            percent_results[name][robot][point] = {}
            for option in options_grid:
                percent_results[name][robot][point][option] = []
                file_name = "finish_percent/" + str(name) + "_" + str(robot) + "_" + str(point) + "_" + str(option) + ".txt"
                with open(file_name) as f:
                    for line in f:
                        data = line.split(" ")
                        time = data[0]
                        percent_results[name][robot][point][option].append(time)

# %%
# import matplotlib.pyplot as plt

# size = range(10, 80, 10)

# # plt.plot(size, time_results[name][robot][point][option], color='tab:red', linestyle='--', label="My (f32)")
# plt.plot(size, time_results[name][robot][point][option], label="My (f32)")

# plt.grid(linestyle='--')
# plt.title("Scalars Squareroot - F7 board - My vs CMSIS - i16 vs i32 vs f32")
# plt.xlabel("Number idx")
# plt.ylabel("ms")
# plt.legend()

# plt.show()
